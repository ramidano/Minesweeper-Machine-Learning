# %%
import numpy as np

train = np.load("train.npz") 
print("Train Boards shape:", train['boards'].shape)
print("Train Mines shape:", train['mines'].shape)

val = np.load("val.npz") 
print("Val Boards shape:", val['boards'].shape)
print("Val Mines shape:", val['mines'].shape)

test = np.load("test.npz") 
print("Test Boards shape:", test['boards'].shape)
print("Test Mines shape:", test['mines'].shape)
# Out:
# Train Boards shape: (1000000, 18, 18)
# Train Mines shape: (1000000, 18, 18)
# Val Boards shape: (100000, 18, 18)
# Val Mines shape: (100000, 18, 18)
# Test Boards shape: (100000, 18, 18)
# Test Mines shape: (100000, 18, 18)
